# %%
import pandas as pd

# %%
person = {
    "first" : 'Iqram',
    "last" : 'Fahromi',
    "email" : 'IqramFahromi@email.com'
}

# %%
person = {
    "first" : ['Iqram'],
    "last" : ['Fahromi'],
    "email" : ['IqramFahromi@email.com']
}

# %%
person = {
    "first" : ['Iqram', 'Max', 'Dove'],
    "last" : ['Fahromi', 'McReary', 'Shampoo'],
    "email" : ['IqramFahromi@email.com', 'MaxMcReary@gmail.com', 'DoveShampoo@yahoo.com']
}

# %%
df1 = pd.DataFrame(person)

# %%
df1
# Out:
#    first     last                   email
# 0  Iqram  Fahromi  IqramFahromi@email.com
# 1    Max  McReary    MaxMcReary@gmail.com
# 2   Dove  Shampoo   DoveShampoo@yahoo.com

# %%
df1['last']
# Out:
# 0    Fahromi
# 1    McReary
# 2    Shampoo
# Name: last, dtype: object

# %%
df1['email']
# Out:
# 0    IqramFahromi@email.com
# 1      MaxMcReary@gmail.com
# 2     DoveShampoo@yahoo.com
# Name: email, dtype: object

# %%
type(df1['email'])
# Out:
# pandas.core.series.Series

# %%
df1.email
# Out:
# 0    IqramFahromi@email.com
# 1      MaxMcReary@gmail.com
# 2     DoveShampoo@yahoo.com
# Name: email, dtype: object

# %%
df1[['email', 'last']]
# Out:
#                     email     last
# 0  IqramFahromi@email.com  Fahromi
# 1    MaxMcReary@gmail.com  McReary
# 2   DoveShampoo@yahoo.com  Shampoo

# %%
df1.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df1
# Out:
#    first     last                   email
# 0  Iqram  Fahromi  IqramFahromi@email.com
# 1    Max  McReary    MaxMcReary@gmail.com
# 2   Dove  Shampoo   DoveShampoo@yahoo.com

# %%
df1.iloc[[0,1]]
# Out:
#    first     last                   email
# 0  Iqram  Fahromi  IqramFahromi@email.com
# 1    Max  McReary    MaxMcReary@gmail.com

# %%
df1.iloc[0,1]
# Out:
# 'Fahromi'

# %%
df1.iloc[[0, 1 ,2], 1]
# Out:
# 0    Fahromi
# 1    McReary
# 2    Shampoo
# Name: last, dtype: object

# %%
df1
# Out:
#    first     last                   email
# 0  Iqram  Fahromi  IqramFahromi@email.com
# 1    Max  McReary    MaxMcReary@gmail.com
# 2   Dove  Shampoo   DoveShampoo@yahoo.com

# %%
df1.iloc[[0, 1], [0, 1]]
# Out:
#    first     last
# 0  Iqram  Fahromi
# 1    Max  McReary

# %%
df1.iloc[0, 1]
# Out:
# 'Fahromi'

# %%
df1.loc[[0, 2], ['email', 'last']]
# Out:
#                     email     last
# 0  IqramFahromi@email.com  Fahromi
# 2   DoveShampoo@yahoo.com  Shampoo

# %%
df1.loc[0:2, ['email', 'last']]
# Out:
#                     email     last
# 0  IqramFahromi@email.com  Fahromi
# 1    MaxMcReary@gmail.com  McReary
# 2   DoveShampoo@yahoo.com  Shampoo

# %%
public_df = pd.read_csv('data/survey_results_public.csv')
schema_df = pd.read_csv('data/survey_results_schema.csv')

# %%
pd.set_option('display.max_columns', 61)
pd.set_option('display.max_rows', 61)

# %%
public_df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
public_df.shape
# Out:
# (64461, 61)

# %%
public_df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
public_df[['Hobbyist']].value_counts()
# Out:
# Hobbyist
# Yes         50388
# No          14028
# dtype: int64

# %%
public_df['Hobbyist'].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
public_df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3        Yes
# 4        Yes
#         ...
# 64456    Yes
# 64457    Yes
# 64458    Yes
# 64459    Yes
# 64460    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
public_df.loc[0:4, 'Hobbyist']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# 3    Yes
# 4    Yes
# Name: Hobbyist, dtype: object

# %%
public_df.loc[[0, 2, 4], 'Hobbyist':'CompFreq']
# Out:
#   Hobbyist   Age Age1stCode CompFreq
# 0      Yes   NaN         13  Monthly
# 2      Yes   NaN         15      NaN
# 4      Yes  31.0         16      NaN
