# %%
person = {
    "first" : ["Iqram", "Max", "Dove", "Abdul"],
    "last" : ["Haris", "McReary", "Shampoo", "Haris"],
    "email": ["IqramHaris@yahoo.com", "MaxMcReary@gmail.com", "DoveShampoo@email.com", "AbdulHaris@email.com"]
}

# %%
import pandas as pd

# %%
df1 = pd.DataFrame(person)

# %%
df1
# Out:
#    first     last                  email
# 0  Iqram    Haris   IqramHaris@yahoo.com
# 1    Max  McReary   MaxMcReary@gmail.com
# 2   Dove  Shampoo  DoveShampoo@email.com
# 3  Abdul    Haris   AbdulHaris@email.com

# %%
df1.reset_index(inplace = True)

# %%
df1['email']
# Out:
# 0     IqramHaris@yahoo.com
# 1     MaxMcReary@gmail.com
# 2    DoveShampoo@email.com
# 3     AbdulHaris@email.com
# Name: email, dtype: object

# %%
df1['last'] == 'Haris'
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# Name: last, dtype: bool

# %%
filt = (df1['last'] == 'Haris')

# %%
df1
# Out:
#    index  first     last                  email
# 0      0  Iqram    Haris   IqramHaris@yahoo.com
# 1      1    Max  McReary   MaxMcReary@gmail.com
# 2      2   Dove  Shampoo  DoveShampoo@email.com
# 3      3  Abdul    Haris   AbdulHaris@email.com

# %%
df1[filt]
# Out:
#    index  first   last                 email
# 0      0  Iqram  Haris  IqramHaris@yahoo.com
# 3      3  Abdul  Haris  AbdulHaris@email.com

# %%
df1.loc[filt]
# Out:
#    index  first   last                 email
# 0      0  Iqram  Haris  IqramHaris@yahoo.com
# 3      3  Abdul  Haris  AbdulHaris@email.com

# %%
df1.loc[filt, 'email']
# Out:
# 0    IqramHaris@yahoo.com
# 3    AbdulHaris@email.com
# Name: email, dtype: object

# %%
filt2 = (df1['last'] == 'Haris') & (df1['first'] == 'Iqram')

# %%
df1[filt2]
# Out:
#    index  first   last                 email
# 0      0  Iqram  Haris  IqramHaris@yahoo.com

# %%
df1[~filt2]
# Out:
#    index  first     last                  email
# 1      1    Max  McReary   MaxMcReary@gmail.com
# 2      2   Dove  Shampoo  DoveShampoo@email.com
# 3      3  Abdul    Haris   AbdulHaris@email.com

# %%
public_df = pd.read_csv('data/survey_results_public.csv', index_col = 'Respondent')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col = 'Column')

# %%
public_df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %%
pd.set_option('display.max_columns', 61)
pd.set_option('display.max_rows', 61)

# %%
public_df.shape
# Out:
# (64461, 60)

# %%
schema_df.sort_index()
# Out:
#                                                                    QuestionText
# Column
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# DatabaseDesireNextYear        Which database environments have you done exte...
# DatabaseWorkedWith            Which database environments have you done exte...
# DevType                       Which of the following describe you? Please se...
# ...

# %%
high_salary = public_df['ConvertedComp'] >= 75000

# %%
public_df.loc[high_salary, ['Age', 'Country', 'LanguageWorkedWith', 'ConvertedComp']]
# Out:
#              Age         Country  \
# Respondent
# 8           36.0   United States
# 16          45.0  United Kingdom
# 17          25.0   United States
# 18          32.0   United States
# 19          24.0   United States
# ...          ...             ...
# 65586        NaN   United States
# 65589        NaN   United States
# 65602        NaN   United States
# 65604        NaN   United States
# 65617        NaN         Germany
#
#                                            LanguageWorkedWith  ConvertedComp
# Respondent
# 8                                                  Python;SQL       116000.0
# 16          Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...       108576.0
# 17                      C#;HTML/CSS;JavaScript;Python;SQL;VBA        79000.0
# 18                        Bash/Shell/PowerShell;HTML/CSS;Perl      1260000.0
# 19          Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;S...        83400.0
# ...

# %%
countries = ['India', 'Indonesia', 'United Kingdom', 'German']
bahasa = ['Python']

# %%
filt3 = public_df['Country'].isin(countries)

# %%
public_df.loc[filt3, ['Country', 'LanguageWorkedWith']]
# Out:
#                    Country                                 LanguageWorkedWith
# Respondent
# 2           United Kingdom                                   JavaScript;Swift
# 7                    India                                    C#;HTML/CSS;PHP
# 10          United Kingdom                HTML/CSS;Java;JavaScript;Python;SQL
# 11          United Kingdom                                C#;JavaScript;Swift
# 16          United Kingdom  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# ...                    ...                                                ...
# 59638       United Kingdom                                    HTML/CSS;Python
# 61490       United Kingdom  Bash/Shell/PowerShell;C;C++;Go;HTML/CSS;JavaSc...
# 62464                India                                                NaN
# 62954                India                                                SQL
# 64236                India                                                NaN
#
# ...

# %%
filt4 = public_df['LanguageWorkedWith'].isin(bahasa)

# %%
public_df.loc[filt4, ['LanguageWorkedWith', 'Country']]
# Out:
#            LanguageWorkedWith        Country
# Respondent
# 55                     Python  United States
# 380                    Python  United States
# 404                    Python          Spain
# 508                    Python  United States
# 518                    Python         Canada
# ...                       ...            ...
# 65037                  Python        Nigeria
# 65205                  Python        Nigeria
# 65528                  Python         Canada
# 9725                   Python         Canada
# 22770                  Python          Egypt
#
# [651 rows x 2 columns]

# %%
filt5 = public_df['LanguageWorkedWith'].str.contains('Python', na = False)

# %%
public_df.loc[filt5, ['LanguageWorkedWith', 'Country']]
# Out:
#                                            LanguageWorkedWith  \
# Respondent
# 3                                    Objective-C;Python;Swift
# 8                                                  Python;SQL
# 10                        HTML/CSS;Java;JavaScript;Python;SQL
# 13                                        C;JavaScript;Python
# 15           Bash/Shell/PowerShell;C;HTML/CSS;Java;Python;SQL
# ...                                                       ...
# 61561       Bash/Shell/PowerShell;HTML/CSS;JavaScript;Perl...
# 62391          C++;HTML/CSS;JavaScript;Python;Ruby;TypeScript
# 63077                 C++;HTML/CSS;Java;JavaScript;Python;SQL
# 63640       Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;Java;J...
# 64867       Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
#
#                        Country
# Respondent
# 3           Russian Federation
# 8                United States
# 10              United Kingdom
# 13                 Netherlands
# 15                      France
# ...
