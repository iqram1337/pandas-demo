# %%
import pandas as pd

# %%
df = pd.read_csv('./data/2.5_day.csv')

# %%
df.head(50)
# Out:
#                         time   latitude   longitude       depth   mag magType  \
# 0   2022-07-12T09:55:03.108Z  28.956100  -97.560600   14.090000  2.80   mb_lg
# 1   2022-07-12T09:01:23.089Z -23.579700  -67.126400  237.320000  4.70      mb
# 2   2022-07-12T08:39:02.816Z  28.997498  -97.582376    3.154663  2.80      ml
# 3   2022-07-12T07:24:58.285Z  60.980500 -150.936500   51.100000  4.70      ml
# 4   2022-07-12T06:47:22.582Z  65.788600 -148.903700    4.200000  2.50      ml
# 5   2022-07-12T06:44:24.016Z   3.142200  127.226900   50.080000  4.70      mb
# 6   2022-07-12T06:16:26.048Z  38.193200 -116.613900   16.000000  2.70      ml
# 7   2022-07-12T05:12:03.987Z  36.042100   70.740100  109.040000  4.20      mb
# 8   2022-07-12T04:35:19.554Z  36.528700   71.233600  198.330000  4.10      mb
# 9   2022-07-12T02:58:59.039Z  60.397500 -149.011700   30.100000  4.30      ml
# 10  2022-07-12T02:56:24.900Z  19.002300  -65.201000   24.000000  3.55      md
# ...

# %%
df.columns
# Out:
# Index(['time', 'latitude', 'longitude', 'depth', 'mag', 'magType', 'nst',
#        'gap', 'dmin', 'rms', 'net', 'id', 'updated', 'place', 'type',
#        'horizontalError', 'depthError', 'magError', 'magNst', 'status',
#        'locationSource', 'magSource'],
#       dtype='object')

# %%
df.shape
# Out:
# (39, 22)

# %%
pd.set_option('display.max_columns', 39)
pd.set_option('display.max_rows', 39)

# %%
df.dtypes
# Out:
# time                object
# latitude           float64
# longitude          float64
# depth              float64
# mag                float64
# magType             object
# nst                float64
# gap                float64
# dmin               float64
# rms                float64
# net                 object
# id                  object
# updated             object
# place               object
# type                object
# horizontalError    float64
# depthError         float64
# magError           float64
# magNst             float64
# status              object
# locationSource      object
# magSource           object
# dtype: object

# %%
filt = df['place'].str.contains('Indonesia')

# %%
indonesia = df[filt]
indonesia
# Out:
#                         time  latitude  longitude  depth  mag magType   nst  \
# 5   2022-07-12T06:44:24.016Z    3.1422   127.2269  50.08  4.7      mb  66.0
# 11  2022-07-12T02:52:06.865Z   -6.0587   104.3751  35.00  4.9      mb  24.0
# 28  2022-07-11T20:37:57.667Z   -0.2373   123.0956  75.84  4.6      mb  38.0
#
#       gap   dmin   rms net          id                   updated  \
# 5    80.0  2.358  0.43  us  us6000i1ri  2022-07-12T07:01:50.040Z
# 11  144.0  2.200  0.87  us  us6000i1qa  2022-07-12T03:06:24.040Z
# 28   58.0  0.862  0.97  us  us6000i1mg  2022-07-11T21:24:19.040Z
#
#                                      place        type  horizontalError  \
# 5          178 km NNW of Tobelo, Indonesia  earthquake              8.0
# 11  120 km SW of Bandar Lampung, Indonesia  earthquake              7.1
# 28         85 km S of Gorontalo, Indonesia  earthquake              9.0
#
#     depthError  magError  magNst    status locationSource magSource
# ...

# %%
# %matplotlib inline

# %%
indonesia['mag'].plot()
# Out:
# <AxesSubplot:>

# %%
filt = df['mag'] >= 5
df[filt][['mag', 'place', 'id', 'time']]
# Out:
#     mag                            place          id                      time
# 14  5.7    145 km SSW of Gataivai, Samoa  us6000i1q3  2022-07-12T02:04:53.068Z
# 18  5.8       125 km NE of Hihifo, Tonga  us6000i1pn  2022-07-12T00:35:05.586Z
# 23  5.6      101 km NNE of Hihifo, Tonga  us6000i1nd  2022-07-11T22:23:36.733Z
# 24  5.0          Kermadec Islands region  us6000i1n0  2022-07-11T21:46:55.665Z
# 26  6.0  84 km ESE of Port-Vila, Vanuatu  us6000i1ms  2022-07-11T21:10:48.633Z
# 27  5.7  88 km ESE of Port-Vila, Vanuatu  us6000i1ml  2022-07-11T21:06:04.537Z

# %%
df.head()
# Out:
#                        time   latitude   longitude       depth  mag magType  \
# 0  2022-07-12T09:55:03.108Z  28.956100  -97.560600   14.090000  2.8   mb_lg
# 1  2022-07-12T09:01:23.089Z -23.579700  -67.126400  237.320000  4.7      mb
# 2  2022-07-12T08:39:02.816Z  28.997498  -97.582376    3.154663  2.8      ml
# 3  2022-07-12T07:24:58.285Z  60.980500 -150.936500   51.100000  4.7      ml
# 4  2022-07-12T06:47:22.582Z  65.788600 -148.903700    4.200000  2.5      ml
#
#     nst    gap      dmin   rms net            id                   updated  \
# 0  49.0  189.0  0.239000  0.38  us    us6000i1sf  2022-07-12T10:16:57.040Z
# 1  25.0   95.0  1.152000  0.70  us    us6000i1s4  2022-07-12T09:23:23.040Z
# 2  17.0   86.0  0.056937  0.70  tx    tx2022nnls  2022-07-12T11:29:40.336Z
# 3   NaN    NaN       NaN  0.72  ak  ak0228vb1a7q  2022-07-12T12:03:03.590Z
# 4   NaN    NaN       NaN  1.26  ak  ak0228vakpc2  2022-07-12T07:50:01.757Z
#
# ...

# %%
df['mag'].plot()
# Out:
# <AxesSubplot:>

# %%
df.fillna(0, inplace=True)

# %%
df
# Out:
#                         time   latitude   longitude       depth   mag magType  \
# 0   2022-07-12T09:55:03.108Z  28.956100  -97.560600   14.090000  2.80   mb_lg
# 1   2022-07-12T09:01:23.089Z -23.579700  -67.126400  237.320000  4.70      mb
# 2   2022-07-12T08:39:02.816Z  28.997498  -97.582376    3.154663  2.80      ml
# 3   2022-07-12T07:24:58.285Z  60.980500 -150.936500   51.100000  4.70      ml
# 4   2022-07-12T06:47:22.582Z  65.788600 -148.903700    4.200000  2.50      ml
# 5   2022-07-12T06:44:24.016Z   3.142200  127.226900   50.080000  4.70      mb
# 6   2022-07-12T06:16:26.048Z  38.193200 -116.613900   16.000000  2.70      ml
# 7   2022-07-12T05:12:03.987Z  36.042100   70.740100  109.040000  4.20      mb
# 8   2022-07-12T04:35:19.554Z  36.528700   71.233600  198.330000  4.10      mb
# 9   2022-07-12T02:58:59.039Z  60.397500 -149.011700   30.100000  4.30      ml
# 10  2022-07-12T02:56:24.900Z  19.002300  -65.201000   24.000000  3.55      md
# ...

# %%
df['place'].unique
# Out:
# <bound method Series.unique of 0                            6 km NE of Nordheim, Texas
# 1     108 km NW of San Antonio de los Cobres, Argentina
# 2                           7 km WNW of Yorktown, Texas
# 3                            14 km SE of Tyonek, Alaska
# 4                  25 km SSE of Stevens Village, Alaska
# 5                       178 km NNW of Tobelo, Indonesia
# 6                                                Nevada
# 7                       70 km NNW of Pārūn, Afghanistan
# 8                   31 km WSW of Ashkāsham, Afghanistan
# 9                         19 km ENE of Primrose, Alaska
# 10                      78 km N of Culebra, Puerto Rico
# 11               120 km SW of Bandar Lampung, Indonesia
# 12                      71 km N of Culebra, Puerto Rico
# 13                        46 km SSW of Mufumbwe, Zambia
# 14                        145 km SSW of Gataivai, Samoa
# 15                                4km ENE of Muscoy, CA
# ...

# %%
df['place'].replace('Nevada', '92 km S of Eureka, Nevada', inplace=True)
df['place'].replace({'Puerto Rico' : '1 km N of Culebra, Puerto Rico', 'Kermadec Islands region': '1 km N of Culebra, Kermadec Islands region' }, inplace=True)

# %%
df['region'] = df['place'].apply(lambda x: x.split(', ')[1])

# %%
df['region'].replace('CA', 'California', inplace=True)

# %%
df['region'].value_counts()
# Out:
# Hawaii                     4
# Alaska                     4
# Nevada                     4
# Puerto Rico                4
# Texas                      3
# Indonesia                  3
# Vanuatu                    2
# Tonga                      2
# California                 2
# Afghanistan                2
# Iran                       2
# Argentina                  1
# Samoa                      1
# Zambia                     1
# Kermadec Islands region    1
# Wyoming                    1
# Oregon                     1
# Japan                      1
# Name: region, dtype: int64

# %%
df
# Out:
#                         time   latitude   longitude       depth   mag magType  \
# 0   2022-07-12T09:55:03.108Z  28.956100  -97.560600   14.090000  2.80   mb_lg
# 1   2022-07-12T09:01:23.089Z -23.579700  -67.126400  237.320000  4.70      mb
# 2   2022-07-12T08:39:02.816Z  28.997498  -97.582376    3.154663  2.80      ml
# 3   2022-07-12T07:24:58.285Z  60.980500 -150.936500   51.100000  4.70      ml
# 4   2022-07-12T06:47:22.582Z  65.788600 -148.903700    4.200000  2.50      ml
# 5   2022-07-12T06:44:24.016Z   3.142200  127.226900   50.080000  4.70      mb
# 6   2022-07-12T06:16:26.048Z  38.193200 -116.613900   16.000000  2.70      ml
# 7   2022-07-12T05:12:03.987Z  36.042100   70.740100  109.040000  4.20      mb
# 8   2022-07-12T04:35:19.554Z  36.528700   71.233600  198.330000  4.10      mb
# 9   2022-07-12T02:58:59.039Z  60.397500 -149.011700   30.100000  4.30      ml
# 10  2022-07-12T02:56:24.900Z  19.002300  -65.201000   24.000000  3.55      md
# ...

# %%
df['status'].value_counts()
# Out:
# reviewed     34
# automatic     5
# Name: status, dtype: int64

# %%
test = df.groupby(['region'])
test

# %%
final_test = test.get_group('Indonesia')

# %%
final_test.to_excel('./data/latihan.xlsx')

# %%
test['magType'].sum()
# Out:
# region
# Afghanistan                     mbmb
# Alaska                      mlmlmlml
# Argentina                         mb
# California                      mlml
# Hawaii                      mlmdmdmd
# Indonesia                     mbmbmb
# Iran                            mbmb
# Japan                             mb
# Kermadec Islands region           mb
# Nevada                      mlmlmlml
# Oregon                            ml
# Puerto Rico                 mdmdmdmd
# Samoa                            mww
# Texas                      mb_lgmlml
# Tonga                         mwwmww
# Vanuatu                       mwwmww
# Wyoming                           ml
# Zambia                            mb
# Name: magType, dtype: object

# %%
df['Time'] = pd.to_datetime(df['Time'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# C:\Anaconda\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\Anaconda\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Time'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
